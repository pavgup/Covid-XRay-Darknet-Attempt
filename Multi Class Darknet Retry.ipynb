# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision.all import *
import pandas as pd
import pathlib

# %% [markdown]
# # Duplicate 500 random `No Finding` Selections from CXR8

# %%
cxr8df = pd.read_csv('CXR8.csv') # this is https://nihcc.app.box.com/v/ChestXray-NIHCC/file/219760887468 
cxr8df.head()
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_001.png                  Hernia            0           3
#
#    Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 0           57              M            PA                 2682     2749
# 1           58              M            PA                 2894     2729
# 2           58              M            PA                 2500     2048
# 3           80              M            PA                 2500     2048
# 4           74              F            PA                 2500     2048
#
#    OriginalImagePixelSpacing[x     y]
# 0                        0.143  0.143
# 1                        0.143  0.143
# 2                        0.168  0.168
# 3                        0.171  0.171
# 4                        0.168  0.168

# %%
FiveHundoRandomNoFindings = cxr8df.loc[cxr8df['Finding Labels'] == 'No Finding'].drop_duplicates(subset=['Patient ID']).sample(500)
#FiveHundoRandomNoFindings = cxr8df.loc[cxr8df['Finding Labels'] == 'No Finding'].sample(500)
FiveHundoRandomNoFindings.head()
# Out:
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 79400   00019501_000.png     No Finding            0       19501           40
# 67679   00016725_000.png     No Finding            0       16725           53
# 102054  00027177_000.png     No Finding            0       27177           51
# 90457   00022519_000.png     No Finding            0       22519           63
# 95851   00025228_000.png     No Finding            0       25228           56
#
#        Patient Gender View Position  OriginalImage[Width  Height]  \
# 79400               M            PA                 2992     2991
# 67679               F            PA                 2048     2500
# 102054              F            PA                 2686     2641
# 90457               M            PA                 2544     3056
# 95851               F            PA                 2546     2991
#
#         OriginalImagePixelSpacing[x     y]
# 79400                         0.143  0.143
# 67679                         0.168  0.168
# 102054                        0.143  0.143
# 90457                         0.139  0.139
# 95851                         0.143  0.143

# %% [markdown]
# # Duplicate 500 random `Pneumonia` Selections from CXR8

# %%
cxr8df = pd.read_csv('CXR8.csv') # this is https://nihcc.app.box.com/v/ChestXray-NIHCC/file/219760887468 
cxr8df.head()
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_001.png                  Hernia            0           3
#
#    Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 0           57              M            PA                 2682     2749
# 1           58              M            PA                 2894     2729
# 2           58              M            PA                 2500     2048
# 3           80              M            PA                 2500     2048
# 4           74              F            PA                 2500     2048
#
#    OriginalImagePixelSpacing[x     y]
# 0                        0.143  0.143
# 1                        0.143  0.143
# 2                        0.168  0.168
# 3                        0.171  0.171
# 4                        0.168  0.168

# %%
FiveHundoRandomPneumonia = cxr8df[cxr8df['Finding Labels'].str.contains('Pneumonia')].drop_duplicates(subset=['Patient ID']).sample(500)
#FiveHundoRandomPneumonia = cxr8df[cxr8df['Finding Labels'].str.contains('Pneumonia')].sample(500)
FiveHundoRandomPneumonia.head()
# Out:
#             Image Index  \
# 91132  00022720_002.png
# 96592  00025444_019.png
# 7997   00002094_006.png
# 51805  00013078_015.png
# 65611  00016191_023.png
#
#                                                               Finding Labels  \
# 91132  Atelectasis|Cardiomegaly|Edema|Effusion|Infiltration|Nodule|Pneumonia
# 96592                                                Consolidation|Pneumonia
# 7997                                            Pleural_Thickening|Pneumonia
# 51805                                                 Infiltration|Pneumonia
# 65611                                                  Atelectasis|Pneumonia
#
#        Follow-up #  Patient ID  Patient Age Patient Gender View Position  \
# 91132            2       22720           17              M            AP
# 96592           19       25444           21              M            PA
# 7997             6        2094           54              M            PA
# 51805           15       13078           42              M            PA
# 65611           23       16191           67              M            PA
#
#        OriginalImage[Width  Height]  OriginalImagePixelSpacing[x        y]
# 91132                 3028     2544                     0.139000  0.139000
# 96592                 2021     2021                     0.194311  0.194311
# 7997                  2856     2638                     0.143000  0.143000
# 51805                 2500     2048                     0.168000  0.168000
# 65611                 2992     2991                     0.143000  0.143000

# %% [markdown]
# # Duplicate Selection of COVID-19 XRays from covid-chestxray-dataset

# %%
coviddf = pd.read_csv('covid-xrays.csv') # this is https://github.com/ieee8023/covid-chestxray-dataset/blob/master/metadata.csv
coviddf.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                               location  folder  \
# 0          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4  Changhua Christian Hospital, Changhua City, Taiwan   images
#
#                                                                  filename  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# 4                                                   nejmc2001573_f1a.jpeg
#
#                     doi                                                 url  \
# 0  10.1056/nejmc2001272  https://www.nejm.org/doi/full/10.1056/NEJMc2001272
# 1  10.1056/nejmc2001272  https://www.nejm.org/doi/full/10.1056/NEJMc2001272
# 2  10.1056/nejmc2001272  https://www.nejm.org/doi/full/10.1056/NEJMc2001272
# 3  10.1056/nejmc2001272  https://www.nejm.org/doi/full/10.1056/NEJMc2001272
# 4  10.1056/NEJMc2001573  https://www.nejm.org/doi/full/10.1056/NEJMc2001573
#
#    license  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             clinical_notes  \
# 0  On January 22, 2020, a 65-year-old man with a history of hypertension, type 2 diabetes, coronary heart disease for which a stent had been implanted, and lung cancer was admitted to the emergency department of Cho Ray Hospital, the referral hospital in Ho Chi Minh City, for low-grade fever and fatigue. He had become ill with fever on January 17, a total of 4 days after he and his wife had flown to Hanoi from the Wuchang district in Wuhan, where outbreaks of 2019-nCoV were occurring. He reported that he had not been exposed to a “wet market” (a market where dead and live animals are sold) in...
# 1  On January 22, 2020, a 65-year-old man with a history of hypertension, type 2 diabetes, coronary heart disease for which a stent had been implanted, and lung cancer was admitted to the emergency department of Cho Ray Hospital, the referral hospital in Ho Chi Minh City, for low-grade fever and fatigue. He had become ill with fever on January 17, a total of 4 days after he and his wife had flown to Hanoi from the Wuchang district in Wuhan, where outbreaks of 2019-nCoV were occurring. He reported that he had not been exposed to a “wet market” (a market where dead and live animals are sold) in...
# 2  On January 22, 2020, a 65-year-old man with a history of hypertension, type 2 diabetes, coronary heart disease for which a stent had been implanted, and lung cancer was admitted to the emergency department of Cho Ray Hospital, the referral hospital in Ho Chi Minh City, for low-grade fever and fatigue. He had become ill with fever on January 17, a total of 4 days after he and his wife had flown to Hanoi from the Wuchang district in Wuhan, where outbreaks of 2019-nCoV were occurring. He reported that he had not been exposed to a “wet market” (a market where dead and live animals are sold) in...
# 3  On January 22, 2020, a 65-year-old man with a history of hypertension, type 2 diabetes, coronary heart disease for which a stent had been implanted, and lung cancer was admitted to the emergency department of Cho Ray Hospital, the referral hospital in Ho Chi Minh City, for low-grade fever and fatigue. He had become ill with fever on January 17, a total of 4 days after he and his wife had flown to Hanoi from the Wuchang district in Wuhan, where outbreaks of 2019-nCoV were occurring. He reported that he had not been exposed to a “wet market” (a market where dead and live animals are sold) in...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         diffuse infiltrates in the bilateral lower lungs
#
#   other_notes Unnamed: 29
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 30 columns]

# %%
AllCovidXRays = coviddf.loc[coviddf['finding'] == 'Pneumonia/Viral/COVID-19'].drop_duplicates(subset=['patientid'])
#AllCovidXRays = coviddf.loc[coviddf['finding'] == 'Pneumonia/Viral/COVID-19']
AllCovidXRays.head()
# Out:
#    patientid  offset  sex   age                   finding RT_PCR_positive  \
# 0          2     0.0    M  65.0  Pneumonia/Viral/COVID-19               Y
# 4          4     0.0    F  52.0  Pneumonia/Viral/COVID-19               Y
# 7          6     0.0  NaN   NaN  Pneumonia/Viral/COVID-19               Y
# 20        11     0.0    M  56.0  Pneumonia/Viral/COVID-19               Y
# 21        12     7.0    M  42.0  Pneumonia/Viral/COVID-19               Y
#
#    survival intubated intubation_present went_icu  ...              date  \
# 0         Y         N                  N        N  ...  January 22, 2020
# 4       NaN         N                  N        N  ...  January 25, 2020
# 7       NaN         Y                  Y        Y  ...   January 6, 2020
# 20        Y       NaN                NaN      NaN  ...              2020
# 21        Y       NaN                NaN      NaN  ...   January 1, 2020
#
#                                                        location  folder  \
# 0                   Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4           Changhua Christian Hospital, Changhua City, Taiwan   images
# 7        Wuhan Jinyintan Hospital, Wuhan, Hubei Province, China  images
# 20  Sunnybrook Health Sciences Centre, Toronto, Ontario, Canada  images
# 21         Tongji Medical College, Wuhan, Hubei Province, China  images
#
#                                                                   filename  \
# 0   auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# 4                                                    nejmc2001573_f1a.jpeg
# 7                                                        lancet-case2a.jpg
# 20                                    1-s2.0-S0140673620303706-fx1_lrg.jpg
# 21                                   nCoV-radiol.2020200269.fig1-day7.jpeg
#
#                               doi  \
# 0            10.1056/nejmc2001272
# 4            10.1056/NEJMc2001573
# 7   10.1016/S0140-6736(20)30211-7
# 20  10.1016/S0140-6736(20)30370-6
# 21      10.1148/radiol.2020200269
#
#                                                                                         url  \
# 0                                        https://www.nejm.org/doi/full/10.1056/NEJMc2001272
# 4                                        https://www.nejm.org/doi/full/10.1056/NEJMc2001573
# 7   https://www.thelancet.com/journals/lancet/article/PIIS0140-6736%2820%2930211-7/fulltext
# 20                      https://www.sciencedirect.com/science/article/pii/S0140673620303706
# 21                                      https://pubs.rsna.org/doi/10.1148/radiol.2020200269
#
#     license  \
# 0       NaN
# 4       NaN
# 7       NaN
# 20      NaN
# 21      NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              clinical_notes  \
# 0   On January 22, 2020, a 65-year-old man with a history of hypertension, type 2 diabetes, coronary heart disease for which a stent had been implanted, and lung cancer was admitted to the emergency department of Cho Ray Hospital, the referral hospital in Ho Chi Minh City, for low-grade fever and fatigue. He had become ill with fever on January 17, a total of 4 days after he and his wife had flown to Hanoi from the Wuchang district in Wuhan, where outbreaks of 2019-nCoV were occurring. He reported that he had not been exposed to a “wet market” (a market where dead and live animals are sold) in...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          diffuse infiltrates in the bilateral lower lungs
# 7                                       Case 2: chest x-ray obtained on Jan 6 (2A). The brightness of both lungs was decreased and multiple patchy shadows were observed; edges were blurred, and large ground-glass opacity and condensation shadows were mainly on the lower right lobe. Tracheal intubation could be seen in the trachea. Heart shadow roughly presents in the normal range. On the left side, the diaphragmatic surface is not clearly displayed. The right side of the diaphragmatic surface was light and smooth and rib phrenic angle was less sharp. Chest x-ray on Jan 10 showed worse status (2B)
# 20  A 56-year-old man presented to our Emergency Department in Toronto, ON, Canada, with fever and non-productive cough, 1 day after returning from a 3-month visit to Wuhan, China. Given this travel history, the transferring ambulance and receiving hospital personnel used appropriate personal protective equipment. He had a medical history of well controlled hypertension. On examination, his maximum temperature was 38·6°C, oxygen saturation was 97% on room air, and respiratory rate was 22 breaths per min—without any signs of respiratory distress. Laboratory investigations showed mild thrombocyt...
# 21                                                                                                                                               On January 1, 2020, a 42-year-old man was admitted to the emergency department of Union Hospital (Tongji Medical College, Wuhan, Hubei Province) due to a high-grade fever (39.6°C [103.28°C]), cough, and fatigue for 1 week. Bilateral coarse breath sounds with wet rales distributed at the bases of both lungs were heard on auscultation. A, Chest radiograph obtained on day 7 after the onset of symptoms shows opacities in the left lower and right upper lobes.
#
#    other_notes Unnamed: 29
# 0          NaN         NaN
# 4          NaN         NaN
# 7          NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Lets Move Data To bkdataset for posterity's sake

# %%
import os
import shutil

# %%
FiveHundoRandomPneumonia.index
# Out:
# Int64Index([ 91132,  96592,   7997,  51805,  65611,  70086,  85546,  90968,
#              90259, 109906,
#             ...
#               8035, 110640,  31267,  86355,  69292, 100866,  19104,  70538,
#              16913,  63004],
#            dtype='int64', length=500)

# %%
FiveHundoRandomNoFindings.index
# Out:
# Int64Index([ 79400,  67679, 102054,  90457,  95851,  33763,  67220,  54155,
#              92553,  23654,
#             ...
#               1836,  72302,  87188,  17080,  15557, 106394,  31834,  94879,
#              49012,  85571],
#            dtype='int64', length=500)

# %%
AllCovidXRays.index
# Out:
# Int64Index([  0,   4,   7,  20,  21,  22,  29,  30,  33,  34,
#             ...
#             891, 894, 909, 919, 930, 934, 935, 936, 937, 939],
#            dtype='int64', length=321)

# %%
print(pathlib.Path.cwd())
for index, row in AllCovidXRays.iterrows():
    if(row['folder'] == 'images'):
        shutil.move('covid-chestxray-dataset/images/'+row['filename'], 'bkdataset/covid/'+row['filename'])    
    else:
        print("Found a non image folder record")
# Out:
# /z2/pgupta/Code/bkcovidmodel/COVID-19
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record
# Found a non image folder record

# %%
print(pathlib.Path.cwd())
for index, row in FiveHundoRandomNoFindings.iterrows():
    shutil.move('CXR8/'+row['Image Index'], 'bkdataset/nofinding/'+row['Image Index'])
# Out:
# /z2/pgupta/Code/bkcovidmodel/COVID-19

# %%
print(pathlib.Path.cwd())
for index, row in FiveHundoRandomPneumonia.iterrows():
    shutil.move('CXR8/'+row['Image Index'], 'bkdataset/pneumonia/'+row['Image Index'])
# Out:
# /z2/pgupta/Code/bkcovidmodel/COVID-19

# %%
path = pathlib.Path('/z2/pgupta/Code/bkcovidmodel/COVID-19/bkdataset')

# %%
def label_func(x): return x.parent.name # get the folder the file is in for a label

# %%
fnames = get_image_files(path)

# %%
dls = ImageDataLoaders.from_path_func(path, fnames, label_func, valid_pct=0.2, 
                                      item_tfms=Resize(256), bs=32, num_workers=4,
                                      batch_tfms=[*aug_transforms(size=(256,256)), 
                                                  Normalize.from_stats(*imagenet_stats)])

# %%
dls.show_batch()

# %%
def conv_block(ni, nf, size=3, stride=1):
    for_pad = lambda s: s if s > 2 else 3
    return nn.Sequential(
        nn.Conv2d(ni, nf, kernel_size=size, stride=stride,
                  padding=(for_pad(size) - 1)//2, bias=False), 
        nn.BatchNorm2d(nf),
        nn.LeakyReLU(negative_slope=0.1, inplace=True)  
    )

# %%
def triple_conv(ni, nf):
    return nn.Sequential(
        conv_block(ni, nf),
        conv_block(nf, ni, size=1),  
        conv_block(ni, nf)
    )

# %%
def maxpooling():
    return nn.MaxPool2d(2, stride=2)

# %%
model = nn.Sequential(
    conv_block(3, 8),
    maxpooling(),
    conv_block(8, 16),
    maxpooling(),
    triple_conv(16, 32),
    maxpooling(),
    triple_conv(32, 64),
    maxpooling(),
    triple_conv(64, 128),
    maxpooling(),
    triple_conv(128, 256),
    conv_block(256, 128, size=1),
    conv_block(128, 256),
    ConvLayer(256, 3),
    Flatten(),
    nn.Linear(507, 3)
)

# %%
#learn = cnn_learner(dls, resnet101, metrics=error_rate)
learn = Learner(dls, model, metrics=[accuracy, error_rate])

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.0009120108559727668, lr_steep=1.3182567499825382e-06)

# %%
print(learn.summary())
# Out:
# Sequential (Input shape: 32)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 8 x 256 x 256
# Conv2d                                    216        True
# BatchNorm2d                               16         True
# LeakyReLU
# MaxPool2d
# ____________________________________________________________________________
#                      32 x 16 x 128 x 128
# Conv2d                                    1152       True
# BatchNorm2d                               32         True
# LeakyReLU
# MaxPool2d
# ____________________________________________________________________________
#                      32 x 32 x 64 x 64
# Conv2d                                    4608       True
# BatchNorm2d                               64         True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 16 x 66 x 66
# Conv2d                                    512        True
# BatchNorm2d                               32         True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 32 x 66 x 66
# Conv2d                                    4608       True
# BatchNorm2d                               64         True
# LeakyReLU
# MaxPool2d
# ____________________________________________________________________________
#                      32 x 64 x 33 x 33
# Conv2d                                    18432      True
# BatchNorm2d                               128        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 32 x 35 x 35
# Conv2d                                    2048       True
# BatchNorm2d                               64         True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 64 x 35 x 35
# Conv2d                                    18432      True
# BatchNorm2d                               128        True
# LeakyReLU
# MaxPool2d
# ____________________________________________________________________________
#                      32 x 128 x 17 x 17
# Conv2d                                    73728      True
# BatchNorm2d                               256        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 64 x 19 x 19
# Conv2d                                    8192       True
# BatchNorm2d                               128        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 128 x 19 x 19
# Conv2d                                    73728      True
# BatchNorm2d                               256        True
# LeakyReLU
# MaxPool2d
# ____________________________________________________________________________
#                      32 x 256 x 9 x 9
# Conv2d                                    294912     True
# BatchNorm2d                               512        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 128 x 11 x 11
# Conv2d                                    32768      True
# BatchNorm2d                               256        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 256 x 11 x 11
# Conv2d                                    294912     True
# BatchNorm2d                               512        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 128 x 13 x 13
# Conv2d                                    32768      True
# BatchNorm2d                               256        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 256 x 13 x 13
# Conv2d                                    294912     True
# BatchNorm2d                               512        True
# LeakyReLU
# ____________________________________________________________________________
#                      32 x 3 x 13 x 13
# Conv2d                                    6912       True
# BatchNorm2d                               6          True
# ReLU
# Flatten
# ____________________________________________________________________________
#                      32 x 3
# Linear                                    1524       True
# ____________________________________________________________________________
#
# Total params: 1,167,586
# Total trainable params: 1,167,586
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7f3dc40c3f70>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model unfrozen
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.fit_one_cycle(30, lr_max=3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.960301</td>
#       <td>1.291180</td>
#       <td>0.200000</td>
#       <td>0.800000</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.923403</td>
#       <td>0.800759</td>
#       <td>0.642308</td>
#       <td>0.357692</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.885572</td>
#       <td>0.902355</td>
#       <td>0.523077</td>
#       <td>0.476923</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.837932</td>
#       <td>9.548325</td>
#       <td>0.211538</td>
#       <td>0.788462</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.849929</td>
#       <td>0.869535</td>
#       <td>0.588462</td>
#       <td>0.411538</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.832952</td>
#       <td>0.871638</td>
#       <td>0.646154</td>
#       <td>0.353846</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.823888</td>
#       <td>0.803754</td>
#       <td>0.615385</td>
#       <td>0.384615</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.799720</td>
#       <td>1.041696</td>
#       <td>0.553846</td>
#       <td>0.446154</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.774970</td>
#       <td>0.797004</td>
#       <td>0.626923</td>
#       <td>0.373077</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.758228</td>
#       <td>0.696613</td>
#       <td>0.715385</td>
#       <td>0.284615</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.748027</td>
#       <td>0.760462</td>
#       <td>0.661538</td>
#       <td>0.338462</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.742447</td>
#       <td>0.742461</td>
#       <td>0.665385</td>
#       <td>0.334615</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0